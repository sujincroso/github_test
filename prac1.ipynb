# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
PROJ_path="/content/drive/MyDrive/Colab_github/github_test/"
# %cd "{PROJ_path}"
# %pwd

# %%
# !git config user.email "bsj09876@gmail.com"
# !git config user.name "sujincroso"

# %%
# !git status
